# %%
import numpy as np

# %%
def softmax(x) :
  e_x = np.exp(x - x.max())
  return e_x / e_x.sum()

# %%
x = np.array([1.0, 1.0, 2.0, 3.0, 2.0, 5.0 , 21.0])
x
# Out:
# array([ 1.,  1.,  2.,  3.,  2.,  5., 21.])

# %%
y = softmax(x)
print(y)
print(y.sum())
# Out:
# [2.06115333e-09 2.06115333e-09 5.60279564e-09 1.52299776e-08
#  5.60279564e-09 1.12535159e-07 9.99999857e-01]
# 1.0
